# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Thomas George Thomas**

# %% [markdown]
# Big data engineer

# %% [markdown]
# *I am interested in being a Data scientist in the healthcare domain since I want to improve the quality of healthcare that everyone receives.*

# %% [markdown]
# ### Calculate the sum of 90 + 10

# %%
90 + 10
# Out:
# 100

# %% [markdown]
# <img src="https://i.pinimg.com/236x/54/dd/2a/54dd2a6c17f894e233848e18eaa242d9.jpg" width="300" >
#
#
#
#
# There are two kinds of people:
# 1. Those who cannot extrapolate from incomplete data
# 2.
#
# ----
#
# > "You miss 100% of the shots that you don't take"
# > - Wayne Gretzky
# > - Micheal Scott
